# %%
#Goal is to get list of playlists from different categories 

#Important Imports
import spotipy as sp
import sys
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import numpy as np
import random
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import json
import time
import sys
import urllib
from sklearn.preprocessing import MultiLabelBinarizer
import requests
from urllib.parse import urlencode
import base64
import webbrowser
import openpyxl

# %%
#Connecting to the Spotify Web API, should ask user to sign in if they haven't done so already 
client_id = "ce672507967540598c451a12f8bcead2"
client_secret = "933b62a83e284d80a6c292e53ba29719"

auth_headers = {
    "client_id": client_id,
    "response_type": "code",
    "redirect_uri": "https://localhost:1234/callback",
    "scope": "user-library-read"
}

webbrowser.open("https://accounts.spotify.com/authorize?" + urlencode(auth_headers))
#If using local host, take code from the search bar and input it into the code string on the next cell
# Out:
# True

# %%
code = 'AQD6NM8HF-p4akNR2iMcQkFhXHhmkkmpDwdBLGHWggo7fnOdbYX4B9Vdz-P863GU2Jc3z5K_SMYH4Caggs9PK6Pji4vB0tE3LkvlETSC7dNUJ-kWrE1By4Kzs6d9lwGOSBurt1YAx2D3dokaIsLrs0wMUbl-pkmW2lrWCVqmrJiCK-vaGhOelb26YJs683FsGMjZLYN4'

# %%
 #Authorizing the code and returning a token 
encoded_credentials = base64.b64encode(client_id.encode() + b':' + client_secret.encode()).decode("utf-8")

token_headers = {
    "Authorization": "Basic " + encoded_credentials,
    "Content-Type": "application/x-www-form-urlencoded"
}

token_data = {
    "grant_type": "authorization_code",
    "code": code,
    "redirect_uri": "https://localhost:1234/callback"
}

r = requests.post("https://accounts.spotify.com/api/token", data=token_data, headers=token_headers)

# %%
token = r.json()["access_token"]

print(token)
# Out:
# BQCS0VK2_Rn-o6ytGu114RebegRhBv8_dyQ3HkLMMREFmhU715ieHr_xIovPo9XxRwG9cV9Ic5ZgGEApRasgz4d1LG3eABN6CWYHGBlJulJEnQ4OVn9zMjaqmsxqtYZEa2eIdVc4YBuTOYpca7netMi7JRdGy9h9dOpNSCa3hBiLKGa5pY9LzHNloF_brs3_Lqqu8xLsIzdD-BYows8

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
s = sp.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlists = s.search(q = 'genre: indie rock', type = 'playlist', limit = 10)

# %%
playlists['playlists']
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=genre%3A+indie+rock&type=playlist&offset=0&limit=10',
#  'items': [{'collaborative': False,
#    'description': 'True indie rock hits.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXb9izPIc0SCS'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb9izPIc0SCS',
#    'id': '37i9dQZF1DXb9izPIc0SCS',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000038d2c0fbb4e007f6dac9db559',
#      'width': None}],
#    'name': 'Indie Rock Hits',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4ODA1NTUyOCwwMDAwMDAwMDkwZDk1OGI1OGM5MjFiMjI5MDY2ZTc5Y2UyOGNhMDU4',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXb9izPIc0SCS/tracks',
#     'total': 101},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DXb9izPIc0SCS'},
#   {'collaborative': False,
#    'description': 'Hop in.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWUoqEG4WY6ce'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUoqEG4WY6ce',
#    'id': '37i9dQZF1DWUoqEG4WY6ce',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000033a724f053daa123f7724f3c7',
#      'width': None}],
#    'name': 'Indie Rock Road Trip',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4NzQ0NDg0MiwwMDAwMDAwMGRhMTAzMmE1MTY2MWZmYjg2MjM0NWFhYmI4MzUzNjA5',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUoqEG4WY6ce/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWUoqEG4WY6ce'},
#   {'collaborative': False,
#    'description': 'The best indie rock vibes — classic and current. ',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX2sUQwD7tbmL'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2sUQwD7tbmL',
#    'id': '37i9dQZF1DX2sUQwD7tbmL',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000032390c211511e2d985935b267',
#      'width': None}],
#    'name': 'Feel-Good Indie Rock',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4ODA5NzYwMCwwMDAwMDAwMDRhNDMyNTljNDI3MjE0OTZkODY2YzUwNzM2N2NiOTg2',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2sUQwD7tbmL/tracks',
#     'total': 150},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX2sUQwD7tbmL'},
#   {'collaborative': False,
#    'description': 'All new indie rock. Featuring new music by Blur.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX30HHrCAl4ZG'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX30HHrCAl4ZG',
#    'id': '37i9dQZF1DX30HHrCAl4ZG',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f0000000356b8cefe526ab719e68136cb',
#      'width': None}],
#    'name': "Today's Indie Rock",
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4ODA5NzY2MCwwMDAwMDAwMDY1NzhjZjgyZTk4YzM3MjYxYTY1N2ZkM2RlZDc5ZGI2',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX30HHrCAl4ZG/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX30HHrCAl4ZG'},
#   {'collaborative': False,
#    'description': 'Welcome to Indie Rock Club. Cover: The Strokes',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX35DWKgAk2B5'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX35DWKgAk2B5',
#    'id': '37i9dQZF1DX35DWKgAk2B5',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000031cba1b9464b3fd4ad5ee9bf5',
#      'width': None}],
#    'name': 'Indie Rock Club',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4NjkyMDU3OCwwMDAwMDAwMDgxMDNlYjFlNTE2YmRlYTdkN2Q1MjBmNjY5NzQxZWFj',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX35DWKgAk2B5/tracks',
#     'total': 75},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX35DWKgAk2B5'},
#   {'collaborative': False,
#    'description': '<a href=spotify:playlist:37i9dQZF1EIV6Dny6HEGMy>Florence + The Machine</a>, <a href=spotify:playlist:37i9dQZF1EIZFSv8zffo2I>Arctic Monkeys</a>, <a href=spotify:playlist:37i9dQZF1EIVNX3XbvPimn>The Neighbourhood</a> and more',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EQqkOPvHGajmW'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EQqkOPvHGajmW',
#    'id': '37i9dQZF1EQqkOPvHGajmW',
#    'images': [{'height': None,
#      'url': 'https://seed-mix-image.spotifycdn.com/v6/img/indie/0SwO7SWeDHJijQ3XNS7xEE/en/large',
#      'width': None}],
#    'name': 'Indie Mix',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4ODUzNjgwMCwwMDAwMDAwMDdhMDYzNDk0ZjcwYmZhMzdlZTU3YjgxYmQ0NDNkOGRh',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EQqkOPvHGajmW/tracks',
#     'total': 50},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1EQqkOPvHGajmW'},
#   {'collaborative': False,
#    'description': 'Kick back and enjoy these classic summer songs.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9fZ7amiNVu6'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9fZ7amiNVu6',
#    'id': '37i9dQZF1DX9fZ7amiNVu6',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000034f288a30074b98312b297e76',
#      'width': None}],
#    'name': 'Feel Good Summer',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4NjkxODgyNiwwMDAwMDAwMDUxNTQzMDU0ZWViNzE3YTUxNWI0MWNmOWZmNWZmODRi',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9fZ7amiNVu6/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX9fZ7amiNVu6'},
#   {'collaborative': False,
#    'description': 'The greatest Alternative Rock songs through the decades. Cover: The Killers',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9GRpeH4CL0S'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9GRpeH4CL0S',
#    'id': '37i9dQZF1DX9GRpeH4CL0S',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003437bdc70e2f03bee9732941e',
#      'width': None}],
#    'name': 'Essential Alternative',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4NjkxODY4MCwwMDAwMDAwMDgzZmQ3MDhkYjI3MDY1MDMxYzIwYzdjYzQ2MmVmMGE5',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9GRpeH4CL0S/tracks',
#     'total': 225},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX9GRpeH4CL0S'},
#   {'collaborative': False,
#    'description': 'These songs rocked the 70s.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWWwzidNQX6jx'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWwzidNQX6jx',
#    'id': '37i9dQZF1DWWwzidNQX6jx',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000033d043e427296ccc0a80eb657',
#      'width': None}],
#    'name': '70s Rock Anthems',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4NjkxOTk1OSwwMDAwMDAwMDQ2ZTZlNzFlODBiMTdmNDAwZTBiY2JkOGI4NWQ5N2Q4',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWwzidNQX6jx/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWWwzidNQX6jx'},
#   {'collaborative': False,
#    'description': 'Music that created modern indie as we know it. Cover: MGMT ',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9LbdoYID5v7'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9LbdoYID5v7',
#    'id': '37i9dQZF1DX9LbdoYID5v7',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003732a8b20f00534714a0b5f22',
#      'width': None}],
#    'name': 'The 2000s Indie Scene',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTY4NjkyMDEyOCwwMDAwMDAwMDMzODgwOTJiM2VkNzAzZGU5ZDg1NTkzYTIxNGRmMzFi',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9LbdoYID5v7/tracks',
#     'total': 75},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX9LbdoYID5v7'}],
#  'limit': 10,
#  'next': 'https://api.spotify.com/v1/search?query=genre%3A+indie+rock&type=playlist&offset=10&limit=10',
#  'offset': 0,
#  'previous': None,
#  'total': 190}
